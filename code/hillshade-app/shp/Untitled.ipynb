# %%
import os

# %%
for i in os.listdir():
    try:
        new = i.split('_')[1].replace(' ','-').lower()
        os(i, new)
    except:
        print(i)
# Out:
# LABEL_Eagle.shp eagle.shp
# LABEL_Pitkin.dbf pitkin.dbf
# LABEL_Custer.shx custer.shx
# LABEL_Lincoln.qpj lincoln.qpj
# LABEL_Saguache.shx saguache.shx
# LABEL_Jefferson.shx jefferson.shx
# LABEL_Weld.prj weld.prj
# LABEL_Lake.dbf lake.dbf
# LABEL_Crowley.shx crowley.shx
# LABEL_Huerfano.shx huerfano.shx
# LABEL_Hinsdale.qpj hinsdale.qpj
# LABEL_Dolores.shx dolores.shx
# LABEL_La Plata.shp la-plata.shp
# LABEL_Las Animas.shp las-animas.shp
# LABEL_Phillips.shp phillips.shp
# LABEL_Washington.shx washington.shx
# LABEL_Kit Carson.shx kit-carson.shx
# LABEL_Mineral.qpj mineral.qpj
# LABEL_Pueblo.qpj pueblo.qpj
# LABEL_Chaffee.prj chaffee.prj
# LABEL_Jackson.shx jackson.shx
# LABEL_Morgan.dbf morgan.dbf
# LABEL_Custer.shp custer.shp
# LABEL_Saguache.shp saguache.shp
# LABEL_Eagle.shx eagle.shx
# LABEL_Prowers.qpj prowers.qpj
# LABEL_Denver.dbf denver.dbf
# LABEL_Jefferson.shp jefferson.shp
# LABEL_Montrose.qpj montrose.qpj
# LABEL_Summit.prj summit.prj
# LABEL_Crowley.shp crowley.shp
# ...
